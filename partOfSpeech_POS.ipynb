# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
txt = nlp("Nasim is a Good Boy. He is trying to be a best boy")
for i in txt:
    print(i,"-->",i.pos_,"-->",spacy.explain(i.pos_))
# Out:
# Nasim --> PROPN --> proper noun
# is --> AUX --> auxiliary
# a --> DET --> determiner
# Good --> ADJ --> adjective
# Boy --> NOUN --> noun
# . --> PUNCT --> punctuation
# He --> PRON --> pronoun
# is --> AUX --> auxiliary
# trying --> VERB --> verb
# to --> PART --> particle
# be --> AUX --> auxiliary
# a --> DET --> determiner
# best --> ADJ --> adjective
# boy --> NOUN --> noun
